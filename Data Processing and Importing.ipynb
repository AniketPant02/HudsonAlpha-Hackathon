# %%
import pandas as pd

# %%
original = pd.read_csv("textfiles.csv")

# %%
original
# Out:
#                                         #Organism/Name           Strain  \
# 0                                     Actinomyces oris             T14V
# 1                               Actinomyces naeslundii       ATCC 27039
# 2                       Actinomyces sp. oral taxon 414            F0588
# 3                                   Actinomyces meyeri             W712
# 4                             Actinomyces radicidentis       CCUG 36733
# 5                               Actinomyces gaoshouyii         pika_114
# 6                               Actinomyces sp. VUL4_3           VUL4_3
# 7                             Actinomyces sp. Chiba101         Chiba101
# 8                      Actinomyces sp. Marseille-P2985  Marseille-P2985
# 9                            Rothia mucilaginosa DY-18            DY-18
# 10                      Rothia dentocariosa ATCC 17931       ATCC 17931
# 11                                        Rothia aeria        JCM 11412
# ...

# %%
d = {'#Organism/Name': original['#Organism/Name'], 'Assembly': original['Assembly'], 'RefSeq FTP': original['RefSeq FTP'], 'GenBank FTP': original['GenBank FTP']}
df = pd.DataFrame(data=d)

# %%
df
# Out:
#                                         #Organism/Name          Assembly  \
# 0                                     Actinomyces oris  GCA_001553935.1
# 1                               Actinomyces naeslundii  GCA_002355915.1
# 2                       Actinomyces sp. oral taxon 414  GCA_001278845.1
# 3                                   Actinomyces meyeri  GCA_001262055.1
# 4                             Actinomyces radicidentis  GCA_001553565.1
# 5                               Actinomyces gaoshouyii  GCA_002076915.1
# 6                               Actinomyces sp. VUL4_3  GCA_001856685.1
# 7                             Actinomyces sp. Chiba101  GCA_002356195.1
# 8                      Actinomyces sp. Marseille-P2985  GCA_900120245.1
# 9                            Rothia mucilaginosa DY-18  GCA_000011025.1
# 10                      Rothia dentocariosa ATCC 17931  GCA_000164695.2
# 11                                        Rothia aeria  GCA_002355935.1
# ...

# %%
df.isnull().sum()
# Out:
# #Organism/Name     0
# Assembly           0
# GenBank FTP       10
# RefSeq FTP        29
# dtype: int64
